# %%
import nltk
import os
import nltk.corpus

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
from nltk.corpus import genesis
genesis.words()
# Out:
# ['In', 'the', 'beginning', 'God', 'created', 'the', ...]

# %%
nltk.corpus.genesis.fileids()
# Out:
# ['english-kjv.txt',
#  'english-web.txt',
#  'finnish.txt',
#  'french.txt',
#  'german.txt',
#  'lolcat.txt',
#  'portuguese.txt',
#  'swedish.txt']

# %%
list1=[]
list1=genesis.words('english-kjv.txt')
for i in list1:
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# see
# ,
# and
# the
# eyes
# of
# my
# brother
# Benjamin
# ,
# that
# it
# is
# my
# mouth
# that
# speaketh
# unto
# you
# .
# And
# ye
# shall
# tell
# my
# father
# of
# all
# my
# glory
# in
# Egypt
# ,
# and
# of
# all
# that
# ye
# have
# seen
# ;
# and
# ye
# shall
# haste
# and
# bring
# down
# my
# father
# hither
# .
# And
# he
# fell
# upon
# his
# brother
# Benjamin
# '
# s
# neck
# ,
# and
# wept
# ;
# and
# Benjamin
# wept
# upon
# his
# neck
# .
# Moreover
# he
# kissed
# all
# his
# brethren
# ,
# and
# wept
# upon
# them
# :
# and
# after
# that
# his
# brethren
# talked
# with
# him
# .
# And
# the
# fame
# thereof
# was
# heard
# in
# Pharaoh
# '
# s
# house
# ,
# saying
# ,
# Joseph
# '
# s
# brethren
# are
# co
# and
# it
# pleased
# Pharaoh
# well
# ,
# and
# his
# servants
# .
# And
# Pharaoh
# said
# unto
# Joseph
# ,
# Say
# unto
# thy
# brethren
# ,
# This
# do
# ye
# ;
# lade
# your
# beasts
# ,
# and
# ...

# %%
print(len(list1))
# Out:
# 44764

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stopwords=set(stopwords.words('english'))
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
temp=[w for w in list1 if not w in stopwords]
temp
# Out:
# ['In',
#  'beginning',
#  'God',
#  'created',
#  'heaven',
#  'earth',
#  '.',
#  'And',
#  'earth',
#  'without',
#  'form',
#  ',',
#  'void',
#  ';',
#  'darkness',
#  'upon',
#  'face',
#  'deep',
#  '.',
#  'And',
#  'Spirit',
#  'God',
#  'moved',
#  'upon',
#  'face',
#  'waters',
#  '.',
#  'And',
#  'God',
#  'said',
#  ',',
#  'Let',
#  'light',
#  ':',
#  'light',
#  '.',
#  'And',
#  'God',
#  'saw',
#  'light',
#  ',',
#  'good',
#  ':',
#  'God',
#  'divided',
#  'light',
#  'darkness',
#  '.',
#  'And',
#  'God',
#  'called',
#  'light',
#  'Day',
#  ',',
#  'darkness',
#  'called',
#  'Night',
#  '.',
#  'And',
#  'evening',
#  'morning',
#  'first',
#  'day',
#  '.',
#  'And',
#  'God',
#  'said',
#  ',',
#  'Let',
#  'firmament',
#  'midst',
#  'waters',
#  ',',
#  'let',
#  'divide',
#  'waters',
#  'waters',
#  '.',
#  'And',
#  'God',
#  'made',
#  'firmament',
#  ',',
#  'divided',
#  'waters',
#  'firmament',
#  'waters',
#  'firmame',
#  '.',
#  'And',
# ...

# %%
print(len(temp))
# Out:
# 26852

# %%
my_stopwords=[]
my_stopwords=list(stopwords)
my_stopwords
# Out:
# ['before',
#  'where',
#  'through',
#  'didn',
#  'll',
#  'further',
#  'i',
#  'did',
#  'couldn',
#  "won't",
#  'she',
#  "you'd",
#  'o',
#  'here',
#  'ma',
#  'does',
#  'under',
#  'not',
#  'than',
#  'shan',
#  'doing',
#  'having',
#  'doesn',
#  'don',
#  'any',
#  'mightn',
#  'again',
#  'y',
#  'are',
#  'what',
#  'is',
#  'needn',
#  'being',
#  're',
#  "shan't",
#  'out',
#  "mustn't",
#  'm',
#  'they',
#  'ours',
#  'were',
#  'each',
#  'these',
#  'was',
#  'the',
#  'hasn',
#  'above',
#  "wouldn't",
#  'down',
#  'why',
#  'just',
#  'won',
#  "wasn't",
#  'haven',
#  'themselves',
#  'we',
#  'our',
#  "don't",
#  'them',
#  'that',
#  'own',
#  'will',
#  'between',
#  'his',
#  'been',
#  "shouldn't",
#  "hasn't",
#  'be',
#  'too',
#  'yours',
#  'had',
#  'same',
#  'while',
#  'there',
#  "aren't",
#  'its',
#  "hadn't",
#  'as',
#  'after',
#  'against',
#  'all',
#  'her',
#  's',
#  'hers',
#  'because',
#  'himself',
#  'of',
#  'from',
# ...

# %%
my_stopwords.append('beginning')
my_stopwords.append('God')
my_stopwords.append('created')
my_stopwords.append('heaven')

# %%
temp=[w for w in list1 if not w in stopwords]
temp
# Out:
# ['In',
#  'beginning',
#  'God',
#  'created',
#  'heaven',
#  'earth',
#  '.',
#  'And',
#  'earth',
#  'without',
#  'form',
#  ',',
#  'void',
#  ';',
#  'darkness',
#  'upon',
#  'face',
#  'deep',
#  '.',
#  'And',
#  'Spirit',
#  'God',
#  'moved',
#  'upon',
#  'face',
#  'waters',
#  '.',
#  'And',
#  'God',
#  'said',
#  ',',
#  'Let',
#  'light',
#  ':',
#  'light',
#  '.',
#  'And',
#  'God',
#  'saw',
#  'light',
#  ',',
#  'good',
#  ':',
#  'God',
#  'divided',
#  'light',
#  'darkness',
#  '.',
#  'And',
#  'God',
#  'called',
#  'light',
#  'Day',
#  ',',
#  'darkness',
#  'called',
#  'Night',
#  '.',
#  'And',
#  'evening',
#  'morning',
#  'first',
#  'day',
#  '.',
#  'And',
#  'God',
#  'said',
#  ',',
#  'Let',
#  'firmament',
#  'midst',
#  'waters',
#  ',',
#  'let',
#  'divide',
#  'waters',
#  'waters',
#  '.',
#  'And',
#  'God',
#  'made',
#  'firmament',
#  ',',
#  'divided',
#  'waters',
#  'firmament',
#  'waters',
#  'firmame',
#  '.',
#  'And',
# ...

# %%
punc=['!','.',',','?','/',':',';']
temp=[w for w in temp if not w in punc]
temp
# Out:
# ['In',
#  'beginning',
#  'God',
#  'created',
#  'heaven',
#  'earth',
#  'And',
#  'earth',
#  'without',
#  'form',
#  'void',
#  'darkness',
#  'upon',
#  'face',
#  'deep',
#  'And',
#  'Spirit',
#  'God',
#  'moved',
#  'upon',
#  'face',
#  'waters',
#  'And',
#  'God',
#  'said',
#  'Let',
#  'light',
#  'light',
#  'And',
#  'God',
#  'saw',
#  'light',
#  'good',
#  'God',
#  'divided',
#  'light',
#  'darkness',
#  'And',
#  'God',
#  'called',
#  'light',
#  'Day',
#  'darkness',
#  'called',
#  'Night',
#  'And',
#  'evening',
#  'morning',
#  'first',
#  'day',
#  'And',
#  'God',
#  'said',
#  'Let',
#  'firmament',
#  'midst',
#  'waters',
#  'let',
#  'divide',
#  'waters',
#  'waters',
#  'And',
#  'God',
#  'made',
#  'firmament',
#  'divided',
#  'waters',
#  'firmament',
#  'waters',
#  'firmame',
#  'And',
#  'God',
#  'called',
#  'firmament',
#  'Heaven',
#  'And',
#  'evening',
#  'morning',
#  'second',
#  'day',
#  'And',
#  'God',
#  'said',
#  'Let',
# ...

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
for w in temp:
  print(ps.stem(w))
# Out:
# Streaming output truncated to the last 5000 lines.
# ward
# hous
# captain
# guard
# prison
# place
# joseph
# bound
# and
# captain
# guard
# charg
# joseph
# serv
# th
# continu
# season
# ward
# and
# dream
# dream
# man
# dream
# one
# night
# man
# accord
# interpret
# dream
# butler
# baker
# king
# egypt
# bound
# prison
# and
# joseph
# came
# unto
# morn
# look
# upon
# behold
# sad
# and
# ask
# pharaoh
# '
# offic
# ward
# lord
# '
# hous
# say
# wherefor
# look
# ye
# sadli
# day
# and
# said
# unto
# we
# dream
# dream
# interpret
# and
# joseph
# said
# unto
# do
# interpret
# belong
# god
# tell
# i
# pray
# and
# chief
# butler
# told
# dream
# joseph
# said
# in
# dream
# behold
# vine
# and
# vine
# three
# branch
# though
# bud
# blossom
# shot
# forth
# cluster
# thereof
# brought
# forth
# ripe
# grap
# and
# pharaoh
# '
# cup
# hand
# i
# took
# grape
# press
# pharaoh
# '
# cup
# i
# gave
# cup
# pharaoh
# '
# hand
# and
# joseph
# said
# unto
# thi
# ...

# %%
tags=nltk.pos_tag(temp,tagset="universal")
tags
# Out:
# [('In', 'ADP'),
#  ('beginning', 'VERB'),
#  ('God', 'NOUN'),
#  ('created', 'VERB'),
#  ('heaven', 'ADJ'),
#  ('earth', 'NOUN'),
#  ('And', 'CONJ'),
#  ('earth', 'NOUN'),
#  ('without', 'ADP'),
#  ('form', 'NOUN'),
#  ('void', 'NOUN'),
#  ('darkness', 'NOUN'),
#  ('upon', 'ADP'),
#  ('face', 'NOUN'),
#  ('deep', 'NOUN'),
#  ('And', 'CONJ'),
#  ('Spirit', 'NOUN'),
#  ('God', 'NOUN'),
#  ('moved', 'VERB'),
#  ('upon', 'ADV'),
#  ('face', 'NOUN'),
#  ('waters', 'NOUN'),
#  ('And', 'CONJ'),
#  ('God', 'NOUN'),
#  ('said', 'VERB'),
#  ('Let', 'NOUN'),
#  ('light', 'ADJ'),
#  ('light', 'NOUN'),
#  ('And', 'CONJ'),
#  ('God', 'NOUN'),
#  ('saw', 'VERB'),
#  ('light', 'ADJ'),
#  ('good', 'ADJ'),
#  ('God', 'NOUN'),
#  ('divided', 'VERB'),
#  ('light', 'ADJ'),
#  ('darkness', 'NOUN'),
#  ('And', 'CONJ'),
#  ('God', 'NOUN'),
#  ('called', 'VERB'),
#  ('light', 'ADJ'),
#  ('Day', 'NOUN'),
#  ('darkness', 'NOUN'),
#  ('called', 'VERB'),
#  ('Night', 'NOUN'),
#  ('And', 'CONJ'),
# ...

# %%
gwords=[]
gwords=genesis.words('german.txt')
print(gwords)
# Out:
# ['Am', 'Anfang', 'schuf', 'Gott', 'Himmel', 'und', ...]

# %%
gtags=nltk.pos_tag(gwords,tagset="universal")
gtags
# Out:
# [('Am', 'NOUN'),
#  ('Anfang', 'NOUN'),
#  ('schuf', 'NOUN'),
#  ('Gott', 'NOUN'),
#  ('Himmel', 'NOUN'),
#  ('und', 'ADP'),
#  ('Erde', 'NOUN'),
#  ('.', '.'),
#  ('Und', 'NOUN'),
#  ('die', 'VERB'),
#  ('Erde', 'NOUN'),
#  ('war', 'NOUN'),
#  ('wüst', 'NOUN'),
#  ('und', 'ADP'),
#  ('leer', 'NOUN'),
#  (',', '.'),
#  ('und', 'ADJ'),
#  ('es', 'X'),
#  ('war', 'NOUN'),
#  ('finster', 'NOUN'),
#  ('auf', 'NOUN'),
#  ('der', 'NOUN'),
#  ('Tiefe', 'NOUN'),
#  (';', '.'),
#  ('und', 'ADJ'),
#  ('der', 'NOUN'),
#  ('Geist', 'NOUN'),
#  ('Gottes', 'NOUN'),
#  ('schwebte', 'VERB'),
#  ('auf', 'ADJ'),
#  ('dem', 'NOUN'),
#  ('Wasser', 'NOUN'),
#  ('.', '.'),
#  ('Und', 'NOUN'),
#  ('Gott', 'NOUN'),
#  ('sprach', 'NOUN'),
#  (':', '.'),
#  ('Es', 'NOUN'),
#  ('werde', 'VERB'),
#  ('Licht', 'NOUN'),
#  ('!', '.'),
#  ('Und', 'NOUN'),
#  ('es', 'VERB'),
#  ('ward', 'ADJ'),
#  ('Licht', 'NOUN'),
#  ('.', '.'),
#  ('Und', 'NOUN'),
#  ('Gott', 'NOUN'),
#  ('sah', 'NOUN'),
#  (',', '.'),
# ...

# %%
from nltk.corpus import names
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...
